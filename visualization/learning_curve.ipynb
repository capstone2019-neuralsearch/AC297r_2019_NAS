# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tr = np.load('/Users/dylanrandle/Downloads/hist_trn.npy')
va = np.load('/Users/dylanrandle/Downloads/hist_val.npy')

# %%
ax = sns.lineplot(x=np.arange(20), y=tr[:,1], label='train')
ax = sns.lineplot(x=np.arange(20), y=va[:,1], label='val', ax = ax)
ax.legend()

# %%
tr = np.load('/Users/dylanrandle/Downloads/experiments/search-GZ-05-ADAM-20191102-100808/hist_trn.npy')
va = np.load('/Users/dylanrandle/Downloads/experiments/search-GZ-05-ADAM-20191102-100808/hist_val.npy')

# %%
tr.shape, va.shape
# Out:
# ((50, 2), (50, 2))

# %%
fig, ax = plt.subplots(1,1)
# ax = sns.lineplot(x=np.arange(10), y=tr[:10,1], fmt='-o', label='train')
# ax = sns.lineplot(x=np.arange(10), y=va[:10,1], label='val', ax = ax)
ax.plot(np.arange(10), tr[:10,1], '-o', label='train')
ax.plot(np.arange(10), va[:10,1], '-o', label='val')
ax.set_yscale('log')
ax.set_ylabel('MSE')
ax.set_xlabel('Epoch')
ax.set_title('Learning curve for GZ Search')
ax.legend()
